# %%
import requests
from bs4 import BeautifulSoup  
from selenium import webdriver
from selenium.webdriver.firefox.options import Options

from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# %%
#options = Options()
#options.add_argument("--headless")
driver = webdriver.Firefox()
url3 ='https://sia.unal.edu.co/Catalogo/facespublico/public/servicioPublico.jsf?taskflowId=task-flow-AC_CatalogoAsignaturas'
driver.get(url3)
page = driver.page_source
soup = BeautifulSoup(page,"html.parser")
print(soup)
driver.quit
# Out:
# <html class="p_AFMaximized" dir="ltr" lang="es"><head><title>servicioPublico.jsf</title><script>if(window.history && window.history.replaceState) window.history.replaceState(null, null, document.location.href.replace(/_afrLoop=[^&^#]*&*|_afrWindowMode=[^&^#]*&*|Adf-Window-Id=[^&^#]*&*|_afrPage=[^&^#]*&*|_afrRedirect=[^&^#]*&*|Adf-Page-Id=[^&^#]*&*|_afrMT=[^&^#]*&*|_afrFS=[^&^#]*&*|_afrMFW=[^&^#]*&*|_afrMFH=[^&^#]*&*|_afrMFDH=[^&^#]*&*|_afrMFDW=[^&^#]*&*|_afrMFC=[^&^#]*&*|_afrMFCI=[^&^#]*&*|_afrMFM=[^&^#]*&*|_afrMFR=[^&^#]*&*|_afrMFG=[^&^#]*&*|_afrMFS=[^&^#]*&*|_afrMFO=[^&^#]*&*|_afrTC=[^&^#]*&*|/g, '').replace(/[\?&]+$|[\?&]+(?=#)/, ''));</script><style afrres="true" type="text/css">
#         /* Fuente corporativa de OCU: Roboto */
#         /*
#         @import url(https://fonts.googleapis.com/css?family=Roboto:100italic,100,300italic,300,400italic,400,500italic,500,700italic,700,900italic,900);
#         */
# ...

# %%
url ='https://dninfoa.unal.edu.co/'
url2 = 'https://sia.unal.edu.co/Catalogo/facespublico/public/servicioPublico.jsf?taskflowId=task-flow-AC_CatalogoAsignaturas'
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 url ='https://dninfoa.unal.edu.co/'
#       2 url2 = 'https://sia.unal.edu.co/Catalogo/facespublico/public/servicioPublico.jsf?taskflowId=task-flow-AC_CatalogoAsignaturas'
# ----> 3 page = driver.page_source
#
# File d:\Proyectos\Scrapping\SiaScraping\myenv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:455, in WebDriver.page_source(self)
#     446 @property
#     447 def page_source(self) -> str:
#     448     """Gets the source of the current page.
#     449
#     450     :Usage:
#    (...)
#     453             driver.page_source
#     454     """
# --> 455     return self.execute(Command.GET_PAGE_SOURCE)["value"]
#
# File d:\Proyectos\Scrapping\SiaScraping\myenv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
# ...

# %%
# Out:
# <!DOCTYPE HTML>
#
# <html class="p_AFMaximized" dir="ltr" lang="es"><head><title>servicioPublico.jsf</title><style afrres="true" type="text/css">
#         /* Fuente corporativa de OCU: Roboto */
#         /*
#         @import url(https://fonts.googleapis.com/css?family=Roboto:100italic,100,300italic,300,400italic,400,500italic,500,700italic,700,900italic,900);
#         */
#         @import url(http://fonts.googleapis.com/css?family=Roboto:100italic,100,300italic,300,400italic,400,500italic,500,700italic,700,900italic,900);
# ...
